# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("WQ_Bacteria_Dash_Data_(Ext).csv")

# %%
df.head(3)
# Out:
#            X          Y  OBJECTID station_id  \
# 0 -98.499553  29.431932         1      S0090
# 1 -98.499553  29.431932         2      S0090
# 2 -98.499553  29.431932         3      S0090
#
#                               sara_short  results      units  latitude_m  \
# 0  San Pedro Creek Upstream Tunnel Inlet      690  MPN/100ml   29.431932
# 1  San Pedro Creek Upstream Tunnel Inlet     5500  MPN/100ml   29.431932
# 2  San Pedro Creek Upstream Tunnel Inlet      980  MPN/100ml   29.431932
#
#    longitude_       waterbody_  ...  isEndDate  recent_dat  \
# 0  -98.499553  San Pedro Creek  ...          0  2019/08/27
# 1  -98.499553  San Pedro Creek  ...          1  2019/08/27
# 2  -98.499553  San Pedro Creek  ...          0  2019/08/27
#
#                  rec_date    max_date                 max_dat  \
# 0  2019/08/28 00:00:00+00  2019/08/16  2019/08/17 00:00:00+00
# 1  2019/08/28 00:00:00+00  2019/08/16  2019/08/17 00:00:00+00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5902 entries, 0 to 5901
# Data columns (total 26 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   X            5902 non-null   float64
#  1   Y            5902 non-null   float64
#  2   OBJECTID     5902 non-null   int64
#  3   station_id   5902 non-null   object
#  4   sara_short   5902 non-null   object
#  5   results      5902 non-null   int64
#  6   units        5902 non-null   object
#  7   latitude_m   5902 non-null   float64
#  8   longitude_   5902 non-null   float64
#  9   waterbody_   5902 non-null   object
#  10  Result1      5902 non-null   float64
#  11  Geomean      5902 non-null   int64
#  12  result1Min   5902 non-null   int64
#  13  result1Max   5902 non-null   int64
#  14  date         5902 non-null   object
#  15  dates        5902 non-null   object
#  16  isEndDate    5902 non-null   int64
#  17  recent_dat   64 non-null     object
# ...

# %%
#checking nulls
df.isnull().sum()
# Out:
# X                 0
# Y                 0
# OBJECTID          0
# station_id        0
# sara_short        0
# results           0
# units             0
# latitude_m        0
# longitude_        0
# waterbody_        0
# Result1           0
# Geomean           0
# result1Min        0
# result1Max        0
# date              0
# dates             0
# isEndDate         0
# recent_dat     5838
# rec_date          0
# max_date          0
# max_dat           0
# URL            5099
# URLName        5099
# ESRI_OID       5838
# GlobalID          0
# county_name       0
# dtype: int64

# %%
df.rec_date.value_counts().sort_values()
# Out:
# 2021/11/17 00:00:00+00       2
# 2021/11/03 00:00:00+00       2
# 2022/01/14 00:00:00+00       4
# 2022/02/10 00:00:00+00       4
# 2021/08/13 00:00:00+00      24
# 2021/08/03 00:00:00+00      25
# 2021/07/27 00:00:00+00      25
# 2021/07/23 00:00:00+00      25
# 2022/02/11 00:00:00+00      27
# 2022/02/02 00:00:00+00      28
# 2022/04/14 00:00:00+00      28
# 2020/08/06 00:00:00+00      37
# 2022/03/18 00:00:00+00      58
# 2022/04/21 00:00:00+00      60
# 2019/08/28 00:00:00+00      64
# 2021/08/18 00:00:00+00      66
# 2022/05/19 00:00:00+00      76
# 2022/05/25 00:00:00+00      90
# 2019/08/29 00:00:00+00     113
# 2022/04/28 00:00:00+00     115
# 2022/04/26 00:00:00+00     139
# 2022/03/25 00:00:00+00     145
# 2022/05/03 00:00:00+00     148
# 2022/05/05 00:00:00+00     149
# 2022/05/13 00:00:00+00     162
# 2022/05/20 00:00:00+00     199
# 2021/07/01 00:00:00+00    1049
# 2022/03/31 00:00:00+00    1464
# 2022/05/26 00:00:00+00    1574
# Name: rec_date, dtype: int64

# %%
df.county_name.value_counts()
# Out:
# Bexar        4025
# Karnes        700
# Wilson        388
# Goliad        344
# Bandera       151
# Medina        128
# BEXAR          78
# Kendall        37
# Victoria       28
# Guadalupe      23
# Name: county_name, dtype: int64

# %%
df.GlobalID
# Out:
# 0       6575896e-74ea-4007-9116-c45b55f1837e
# 1       06eb8d94-573b-48a5-ab6f-c73ff05305ff
# 2       a72cb2d4-1f36-4001-9b38-ad83342e983e
# 3       c86f3c8b-b5a9-489e-8841-b9c4bd71e4ae
# 4       2f5ab513-5a27-4525-a7cc-debe8d4467e6
#                         ...
# 5897    3d74c896-81f8-4100-844c-6bb066d02b56
# 5898    2229c6e0-d3e0-44cc-b00f-5e5d54c08c0c
# 5899    cbc4795e-820e-495f-916b-03a83e2a2663
# 5900    1ef5aaf7-733d-4c3b-9b41-d1100ccd0a21
# 5901    08877329-8763-495b-a4fe-26e5373a5281
# Name: GlobalID, Length: 5902, dtype: object

# %% [markdown]
# #### Cleaning that needs to be done:
# - Dropping nulls columns
# - cleaning county names (ex. Bexar vs BEXAR)and move data to one column
# - understand what min/max dates mean
# - dropping time on dates columns (nothing recorded there)
# - understanding why the dates of record are what they are...no order/pattern, so why recorded then?
# - change dates to DateTime
# - parse GlobalID

# %%
df[df.Geomean >= 126]
# Out:
#               X          Y  OBJECTID station_id  \
# 0    -98.499553  29.431932         1      S0090
# 1    -98.499553  29.431932         2      S0090
# 2    -98.499553  29.431932         3      S0090
# 3    -98.499553  29.431932         4      S0090
# 4    -98.499553  29.431932         5      S0090
# ...         ...        ...       ...        ...
# 5893 -97.772200  28.920300     86656      20539
# 5894 -97.991900  29.229400     86657      20776
# 5898 -98.474900  29.369700     86661      21547
# 5900 -98.538600  29.427000     86663      S0067
# 5901 -98.498200  29.431600     86664      S0069
#
#                                  sara_short  results      units  latitude_m  \
# 0     San Pedro Creek Upstream Tunnel Inlet      690  MPN/100ml   29.431932
# 1     San Pedro Creek Upstream Tunnel Inlet     5500  MPN/100ml   29.431932
# 2     San Pedro Creek Upstream Tunnel Inlet      980  MPN/100ml   29.431932
# 3     San Pedro Creek Upstream Tunnel Inlet      820  MPN/100ml   29.431932
# ...

# %%
plt.figure(figsize=(10,8))

sns.barplot(data=df, x='Geomean', y='rec_date')
# Out:
# <AxesSubplot:xlabel='Geomean', ylabel='rec_date'>

# %%
sns.scatterplot(data=df, x='rec_date', y='Geomean')
# Out:
# <AxesSubplot:xlabel='rec_date', ylabel='Geomean'>

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(data=df, x='rec_date', y='Geomean', hue='county_name')
# Out:
# <AxesSubplot:xlabel='rec_date', ylabel='Geomean'>

# %%
plt.figure(figsize=(10,8))
sns.lineplot(data=df, x="rec_date", y="Geomean")
# Out:
# <AxesSubplot:xlabel='rec_date', ylabel='Geomean'>
